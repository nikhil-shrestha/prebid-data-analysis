# %%
import numpy as np
from kmeans import plot_k_means

# %%
N = 1000
D = 2

# %%
R_inner = 5
R_outer = 10

# %%
# distance from origin is radius + random normal
# angle theta is uniformly distributed between (0, 2pi)
R1 = np.random.randn(N//2) + R_inner
theta = 2*np.pi*np.random.random(N//2)
X_inner = np.concatenate([[R1 * np.cos(theta)], [R1 * np.sin(theta)]]).T

R2 = np.random.randn(N//2) + R_outer
theta = 2*np.pi*np.random.random(N//2)
X_outer = np.concatenate([[R2 * np.cos(theta)], [R2 * np.sin(theta)]]).T

X = np.concatenate([ X_inner, X_outer ])

# %%
plot_k_means(X, 2, beta=0.1, show_plots=True)
# Out:
# Final cost 41033.036267291005
# (array([[ 3.21074698, -3.34047713],
#         [-3.39294769,  3.49866656]]),
#  array([[9.27620718e-05, 9.99907238e-01],
#         [3.99032500e-05, 9.99960097e-01],
#         [1.71671213e-03, 9.98283288e-01],
#         ...,
#         [1.39770820e-07, 9.99999860e-01],
#         [4.66435778e-01, 5.33564222e-01],
#         [9.99978542e-01, 2.14577367e-05]]))

# %%
# elongated clusters
X = np.zeros((1000, 2))
X[:500,:] = np.random.multivariate_normal([0, 0], [[1, 0], [0, 20]], 500)
X[500:,:] = np.random.multivariate_normal([5, 0], [[1, 0], [0, 20]], 500)
plot_k_means(X, 2, beta=0.1, show_plots=True)
# Out:
# Final cost 15472.023931285918
# (array([[ 2.50914173, -3.68321164],
#         [ 2.57146581,  3.10769236]]),
#  array([[1.25508848e-03, 9.98744912e-01],
#         [8.83194016e-01, 1.16805984e-01],
#         [5.82920369e-04, 9.99417080e-01],
#         ...,
#         [9.98802346e-01, 1.19765413e-03],
#         [3.20550075e-01, 6.79449925e-01],
#         [2.41381333e-01, 7.58618667e-01]]))

# %%
# different density
X = np.zeros((1000, 2))
X[:950,:] = np.array([0,0]) + np.random.randn(950, 2)
X[950:,:] = np.array([3,0]) + np.random.randn(50, 2)
plot_k_means(X, 2, show_plots=True)
# Out:
# Final cost 1647.8279573167256
# (array([[-0.52511793, -0.23459688],
#         [ 1.2772562 ,  0.25081419]]),
#  array([[1.66906206e-04, 9.99833094e-01],
#         [9.99997213e-01, 2.78723058e-06],
#         [1.96983641e-04, 9.99803016e-01],
#         ...,
#         [1.51687229e-22, 1.00000000e+00],
#         [5.09322900e-07, 9.99999491e-01],
#         [3.50754167e-11, 1.00000000e+00]]))
